# %% [markdown]
# # EDSA Movie Recommendation 2022

# %% [markdown]
# **Lungisa Joctrey**

# %% [markdown]
# ### Table of Contents

# %% [markdown]
# 1. Introduction
# 2. Importing Packages
# 3. Loading Data
# 4. Exploratory Data Analysis
# 5. Feature Engineering
# 6. Modelling
# 7. Model Evaluation

# %% [markdown]
# ### 1. Introduction

# %% [markdown]
# In today’s technology driven world, recommender systems are socially and economically critical to ensure that individuals can make optimised choices surrounding the content they engage with on a daily basis. One application where this is especially true is movie recommendations; where intelligent algorithms can help viewers find great titles from tens of thousands of options.
#
# In this notebook were going to build a movie recommender using various models.

# %% [markdown]
# ### 2. Importing Packages

# %% [markdown]
# We are now importing the packages we need for this project.

# %%
#standard data science packages
import pandas as pd
import numpy as np

#for displaying an image from the url
from IPython.display import Image

# %% [markdown]
# ### 3. Loading Data

# %% [markdown]
# We no load our train and test datasets

# %%
#loading data
df_train = pd.read_csv('train.csv')
df_movies = pd.read_csv('movies.csv')
df_gscores = pd.read_csv('genome_scores.csv')
df_gtags = pd.read_csv('genome_tags.csv')
df_imdb_data = pd.read_csv('imdb_data.csv')
df_tags = pd.read_csv('tags.csv')
df_links = pd.read_csv('links.csv')




df_test = pd.read_csv('test.csv')

# %%
image = Image("https://github.com/Explore-AI/unsupervised-predict-streamlit-template/raw/master/resources/imgs/Image_header.png")
image

# %% [markdown]
# Lets us display the data to see how it looks like. We shall desplay only 5 entries.

# %%
df_train.head()
# Out:
#    userId  movieId  rating   timestamp
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_gscores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %%
df_gtags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
df_imdb_data.head()
# Out:
#    movieId                                         title_cast  \
# 0        1  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        2  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        3  Walter Matthau|Jack Lemmon|Sophia Loren|Ann-Ma...
# 3        4  Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        5  Steve Martin|Diane Keaton|Martin Short|Kimberl...
#
#               director  runtime       budget  \
# 0        John Lasseter     81.0  $30,000,000
# 1   Jonathan Hensleigh    104.0  $65,000,000
# 2  Mark Steven Johnson    101.0  $25,000,000
# 3       Terry McMillan    124.0  $16,000,000
# 4       Albert Hackett    106.0  $30,000,000
#
#                                        plot_keywords
# 0                   toy|rivalry|cowboy|cgi animation
# 1                   board game|adventurer|fight|game
# 2                         boat|lake|neighbor|rivalry
# 3  black american|husband wife relationship|betra...
# ...

# %%
df_tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# ### 4. Exploratory Data Analysis

# %% [markdown]
# ### 5. Feature Engineering

# %% [markdown]
# ### 6. Modelling

# %% [markdown]
# ### 7. Model Evaluation
